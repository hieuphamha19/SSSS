# %%
# !pip install gdown
import gdown
# !gdown --id 1bS3Tnk73namGTGiaDW5b4m8IvD83ZlyK
# Out:
# Requirement already satisfied: gdown in /home/student02/anaconda3/envs/semi/lib/python3.11/site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /home/student02/anaconda3/envs/semi/lib/python3.11/site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /home/student02/anaconda3/envs/semi/lib/python3.11/site-packages (from gdown) (3.14.0)
# Requirement already satisfied: requests[socks] in /home/student02/anaconda3/envs/semi/lib/python3.11/site-packages (from gdown) (2.28.2)
# Requirement already satisfied: tqdm in /home/student02/anaconda3/envs/semi/lib/python3.11/site-packages (from gdown) (4.65.2)
# Requirement already satisfied: soupsieve>1.2 in /home/student02/anaconda3/envs/semi/lib/python3.11/site-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/student02/anaconda3/envs/semi/lib/python3.11/site-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/student02/anaconda3/envs/semi/lib/python3.11/site-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/student02/anaconda3/envs/semi/lib/python3.11/site-packages (from requests[socks]->gdown) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /home/student02/anaconda3/envs/semi/lib/python3.11/site-packages (from requests[socks]->gdown) (2024.12.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/student02/anaconda3/envs/semi/lib/python3.11/site-packages (from requests[socks]->gdown) (1.7.1)
# /home/student02/anaconda3/envs/semi/lib/python3.11/site-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1bS3Tnk73namGTGiaDW5b4m8IvD83ZlyK
# From (redirected): https://drive.google.com/uc?id=1bS3Tnk73namGTGiaDW5b4m8IvD83ZlyK&confirm=t&uuid=d96c9c20-22a2-4e71-857b-c7c3eaf7cd4a
# To: /home/student02/.test/Projects/SSSS/train.zip
# 100%|██████████████████████████████████████| 93.4M/93.4M [00:08<00:00, 11.0MB/s]

# %%
# !mkdir data
# !mkdir data/fugc
# !unzip train.zip -d data/fugc
# Out:
# Archive:  train.zip
#    creating: data/fugc/train/
#   inflating: data/fugc/train/Data-sharing Agreement_FUGC2025.docx
#    creating: data/fugc/train/labeled_data/
#    creating: data/fugc/train/labeled_data/images/
#   inflating: data/fugc/train/labeled_data/images/0001.png
#   inflating: data/fugc/train/labeled_data/images/0002.png
#   inflating: data/fugc/train/labeled_data/images/0003.png
#   inflating: data/fugc/train/labeled_data/images/0004.png
#   inflating: data/fugc/train/labeled_data/images/0005.png
#   inflating: data/fugc/train/labeled_data/images/0006.png
#   inflating: data/fugc/train/labeled_data/images/0007.png
#   inflating: data/fugc/train/labeled_data/images/0008.png
#   inflating: data/fugc/train/labeled_data/images/0009.png
#   inflating: data/fugc/train/labeled_data/images/0010.png
#   inflating: data/fugc/train/labeled_data/images/0011.png
#   inflating: data/fugc/train/labeled_data/images/0012.png
#   inflating: data/fugc/train/labeled_data/images/0013.png
#   inflating: data/fugc/train/labeled_data/images/0014.png
#   inflating: data/fugc/train/labeled_data/images/0015.png
#   inflating: data/fugc/train/labeled_data/images/0016.png
#   inflating: data/fugc/train/labeled_data/images/0017.png
#   inflating: data/fugc/train/labeled_data/images/0018.png
#   inflating: data/fugc/train/labeled_data/images/0019.png
#   inflating: data/fugc/train/labeled_data/images/0020.png
#   inflating: data/fugc/train/labeled_data/images/0021.png
#   inflating: data/fugc/train/labeled_data/images/0022.png
#   inflating: data/fugc/train/labeled_data/images/0023.png
#   inflating: data/fugc/train/labeled_data/images/0024.png
#   inflating: data/fugc/train/labeled_data/images/0025.png
#   inflating: data/fugc/train/labeled_data/images/0026.png
#   inflating: data/fugc/train/labeled_data/images/0027.png
#   inflating: data/fugc/train/labeled_data/images/0028.png
#   inflating: data/fugc/train/labeled_data/images/0029.png
#   inflating: data/fugc/train/labeled_data/images/0030.png
#   inflating: data/fugc/train/labeled_data/images/0031.png
#   inflating: data/fugc/train/labeled_data/images/0032.png
#   inflating: data/fugc/train/labeled_data/images/0033.png
#   inflating: data/fugc/train/labeled_data/images/0034.png
#   inflating: data/fugc/train/labeled_data/images/0035.png
#   inflating: data/fugc/train/labeled_data/images/0036.png
#   inflating: data/fugc/train/unlabeled_data/images/0431.png
#   inflating: data/fugc/train/unlabeled_data/images/0432.png
#   inflating: data/fugc/train/unlabeled_data/images/0433.png
#   inflating: data/fugc/train/unlabeled_data/images/0434.png
#   inflating: data/fugc/train/unlabeled_data/images/0435.png
#   inflating: data/fugc/train/unlabeled_data/images/0436.png
#   inflating: data/fugc/train/unlabeled_data/images/0437.png
#   inflating: data/fugc/train/unlabeled_data/images/0438.png
#   inflating: data/fugc/train/unlabeled_data/images/0439.png
#   inflating: data/fugc/train/unlabeled_data/images/0440.png
#   inflating: data/fugc/train/unlabeled_data/images/0441.png
#   inflating: data/fugc/train/unlabeled_data/images/0442.png
#   inflating: data/fugc/train/unlabeled_data/images/0443.png
#   inflating: data/fugc/train/unlabeled_data/images/0444.png
#   inflating: data/fugc/train/unlabeled_data/images/0445.png
#   inflating: data/fugc/train/unlabeled_data/images/0446.png
#   inflating: data/fugc/train/unlabeled_data/images/0447.png
#   inflating: data/fugc/train/unlabeled_data/images/0448.png
#   inflating: data/fugc/train/unlabeled_data/images/0449.png
#   inflating: data/fugc/train/unlabeled_data/images/0450.png

# %%
import os
import numpy as np
import random
import cv2
import matplotlib.pyplot as plt

def create_folds(proceeded_folder='./proceeded_data', num_folds=5):
    folds_dir = proceeded_folder
    os.makedirs(folds_dir, exist_ok=True)

    image_files = os.listdir(os.path.join(proceeded_folder, 'images'))
    label_files = os.listdir(os.path.join(proceeded_folder, 'labels'))

    assert all(img[:-4] == lbl[:-4] for img, lbl in zip(sorted(image_files), sorted(label_files))), "Image and label names do not match."

    file_names = [img[:-4] for img in image_files]

    random.shuffle(file_names)

    folds = np.array_split(file_names, num_folds)

    for i in range(num_folds):
        with open(os.path.join(folds_dir, f'fold_label_{i + 1}.txt'), 'w') as f:
            for name in folds[i]:
                f.write(f"{name}.npy\n")
                
def save_images_and_labels_as_npy(images_dirs, labels_dirs, output_npy_dir):
    for dataset_name, image_dir, label_dir in zip(['fugc'], images_dirs, labels_dirs):
        dataset_image_dir = os.path.join(output_npy_dir, dataset_name, 'train', 'labeled_data', 'images')
        dataset_label_dir = os.path.join(output_npy_dir, dataset_name, 'train', 'labeled_data', 'labels')
        
        os.makedirs(dataset_image_dir, exist_ok=True)
        os.makedirs(dataset_label_dir, exist_ok=True)

        for root, dirs, files in os.walk(image_dir):
            for file in files:
                if file.endswith('.png'):
                    image_path = os.path.join(root, file)
                    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
                    if image is not None:
                        image_npy_path = os.path.join(dataset_image_dir, f"{os.path.splitext(file)[0]}.npy")
                        np.save(image_npy_path, image)
                        print(f"Saved image to {image_npy_path}.")
                    else:
                        print(f"Warning: Could not read image at {image_path}.")

                    # Similarly for labels
                    label_path = os.path.join(label_dir, file)  # Assume labels have same filename
                    if os.path.exists(label_path):
                        label = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE)  # Read as grayscale
                        if label is not None:
                            label_npy_path = os.path.join(dataset_label_dir, f"{os.path.splitext(file)[0]}.npy")
                            np.save(label_npy_path, label)
                            print(f"Saved label to {label_npy_path}.")
                        else:
                            print(f"Warning: Could not read label at {label_path}.")
                    else:
                        print(f"Warning: Label not found for {file}.")

def save_unlabeled_images_as_npy(unlabeled_dirs, output_npy_dir):
    for dataset_name, unlabeled_dir in zip(['fugc'], unlabeled_dirs):
        dataset_unlabeled_dir = os.path.join(output_npy_dir, dataset_name, 'train', 'unlabeled_data', 'images')
        os.makedirs(dataset_unlabeled_dir, exist_ok=True)

        # Create unlabeled.txt file
        unlabeled_txt_path = os.path.join(output_npy_dir, dataset_name, 'train', 'unlabeled_data', 'unlabeled.txt')
        os.makedirs(os.path.dirname(unlabeled_txt_path), exist_ok=True)
        unlabeled_files = []

        for root, dirs, files in os.walk(unlabeled_dir):
            for file in files:
                if file.endswith('.png'):
                    image_path = os.path.join(root, file)
                    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
                    if image is not None:
                        image_npy_path = os.path.join(dataset_unlabeled_dir, f"{os.path.splitext(file)[0]}.npy")
                        np.save(image_npy_path, image)
                        print(f"Saved unlabeled image to {image_npy_path}.")
                        unlabeled_files.append(f"{os.path.splitext(file)[0]}.npy")
                    else:
                        print(f"Warning: Could not read unlabeled image at {image_path}.")

        # Write unlabeled file names to unlabeled.txt
        with open(unlabeled_txt_path, 'w') as f:
            for file in unlabeled_files:
                f.write(f"{file}\n")

images_dirs = 'data/fugc/train/labeled_data/images'
labels_dirs = 'data/fugc/train/labeled_data/labels'
unlabeled_dirs = 'data/fugc/train/unlabeled_data/images'

print("Images directory content:", os.listdir(images_dirs))
print("Labels directory content:", os.listdir(labels_dirs))

train_images_dirs = [
    'data/fugc/train/labeled_data/images',    
]

train_labels_dirs = [
    'data/fugc/train/labeled_data/labels',
]

unlabeled_images_dirs = [
    'data/fugc/train/unlabeled_data/images',
]

output_npy_dir = 'data_processed'
    
save_images_and_labels_as_npy(train_images_dirs, train_labels_dirs, output_npy_dir)
save_unlabeled_images_as_npy(unlabeled_images_dirs, output_npy_dir)

# Create folds after saving the data
create_folds(os.path.join(output_npy_dir, 'fugc', 'train', 'labeled_data'), num_folds=5)
# Out:
# Images directory content: ['0041.png', '0035.png', '0032.png', '0003.png', '0036.png', '0034.png', '0024.png', '0018.png', '0023.png', '0031.png', '0011.png', '0044.png', '0016.png', '0028.png', '0009.png', '0007.png', '0033.png', '0039.png', '0029.png', '0025.png', '0006.png', '0015.png', '0043.png', '0037.png', '0047.png', '0021.png', '0010.png', '0017.png', '0026.png', '0050.png', '0030.png', '0048.png', '0022.png', '0001.png', '0019.png', '0027.png', '0045.png', '0005.png', '0042.png', '0012.png', '0004.png', '0014.png', '0040.png', '0020.png', '0013.png', '0038.png', '0046.png', '0049.png', '0002.png', '0008.png']
# Labels directory content: ['0041.png', '0035.png', '0032.png', '0003.png', '0036.png', '0034.png', '0024.png', '0018.png', '0023.png', '0031.png', '0011.png', '0044.png', '0016.png', '0028.png', '0009.png', '0007.png', '0033.png', '0039.png', '0029.png', '0025.png', '0006.png', '0015.png', '0043.png', '0037.png', '0047.png', '0021.png', '0010.png', '0017.png', '0026.png', '0050.png', '0030.png', '0048.png', '0022.png', '0001.png', '0019.png', '0027.png', '0045.png', '0005.png', '0042.png', '0012.png', '0004.png', '0014.png', '0040.png', '0020.png', '0013.png', '0038.png', '0046.png', '0049.png', '0002.png', '0008.png']
# Saved image to data_processed/fugc/train/labeled_data/images/0041.npy.
# Saved label to data_processed/fugc/train/labeled_data/labels/
npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0279.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0269.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0249.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0026.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0050.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0375.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0383.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0293.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0429.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0178.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0171.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0408.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0418.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0368.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0433.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0440.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0093.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0370.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0030.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0105.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0048.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0022.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0001.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0264.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0439.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0176.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0306.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0138.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0172.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0296.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0019.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0372.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0399.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0189.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0427.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0359.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0307.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0070.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0407.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0352.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0066.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0027.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0241.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0315.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0071.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0320.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0125.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0128.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0334.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0155.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0239.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0278.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0057.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0199.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0254.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0132.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0358.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0380.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0436.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0104.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0045.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0072.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0344.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0283.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0292.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0191.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0099.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0160.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0090.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0277.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0213.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0061.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0058.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0424.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0371.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0281.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0074.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0210.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0158.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0396.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0350.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0237.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0111.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0114.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0135.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0313.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0227.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0443.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0417.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0005.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0298.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0430.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0240.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0447.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0246.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0096.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0299.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0209.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0068.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0137.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0042.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0406.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0215.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0012.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0414.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0255.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0346.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0004.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0142.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0014.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0153.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0367.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0369.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0351.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0229.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0301.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0212.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0040.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0379.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0100.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0412.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0075.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0260.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0141.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0378.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0423.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0361.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0262.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0441.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0421.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0411.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0101.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0336.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0444.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0206.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0020.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0013.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0312.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0038.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0173.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0355.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0162.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0046.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0196.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0314.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0263.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0280.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0220.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0415.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0130.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0420.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0136.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0049.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0002.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0146.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0119.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0265.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0377.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0108.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0167.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0214.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0069.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0198.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0145.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0353.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0161.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0294.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0257.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0405.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0126.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0073.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0127.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0201.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0139.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0373.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0445.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0008.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0175.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0426.npy.
# Saved unlabeled image to data_processed/fugc/train/unlabeled_data/images/0401.npy.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
# show images and labels
dataset_name = 'fugc'
fold = 1

def show_images_and_labels(dataset_name, fold):
    dataset_image_dir = '/home/student02/hieu/Projects/SSSS/data_processed/fugc/train/labeled_data/images/'
    dataset_label_dir = '/home/student02/hieu/Projects/SSSS/data_processed/fugc/train/labeled_data/labels/'
    
    image_files = os.listdir(dataset_image_dir)
    label_files = os.listdir(dataset_label_dir)
    
    # Randomly select 5 images
    random_indices = np.random.choice(len(image_files), 5, replace=False)
    selected_image_files = [image_files[i] for i in random_indices]
    selected_label_files = [label_files[i] for i in random_indices]
    
    plt.figure(figsize=(20,10))
    for i, (image_file, label_file) in enumerate(zip(selected_image_files, selected_label_files)):
        image = np.load(os.path.join(dataset_image_dir, image_file))
        label = np.load(os.path.join(dataset_label_dir, label_file))
        
        plt.subplot(2, 5, i+1)
        plt.imshow(image)
        plt.title(f'Image {image_file}')
        plt.axis('off')
        
        plt.subplot(2, 5, i+6)
        plt.imshow(label, cmap='gray')
        plt.title(f'Label {label_file}')
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

show_images_and_labels(dataset_name, fold)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 38
#      35     plt.tight_layout()
#      36     plt.show()
# ---> 38 show_images_and_labels(dataset_name, fold)
#
# Cell In[9], line 12, in show_images_and_labels(dataset_name, fold)
#       9 dataset_image_dir = '/home/student02/hieu/Projects/SSSS/data_processed/fugc/train/labeled_data/images/'
#      10 dataset_label_dir = '/home/student02/hieu/Projects/SSSS/data_processed/fugc/train/labeled_data/labels/'
# ---> 12 image_files = os.listdir(dataset_image_dir)
#      13 label_files = os.listdir(dataset_label_dir)
#      15 # Randomly select 5 images
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/student02/hieu/Projects/SSSS/data_processed/fugc/train/labeled_data/images/'
